# %% [markdown]
# # Linear Regression from Scratch
#
# Implement linear regression using gradient descent.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)

X = np.random.randn(100, 1)
y = 3*X.ravel() + 2 + np.random.randn(100)*0.5

# %%
def linear_regression_gd(X, y, lr=0.01, epochs=1000):
    m = len(y)
    X_b = np.c_[np.ones(m), X]  # Add bias
    w = np.zeros(X_b.shape[1])
    losses = []
    
    for _ in range(epochs):
        pred = X_b @ w
        error = pred - y
        loss = np.mean(error**2)
        losses.append(loss)
        gradient = (2/m) * X_b.T @ error
        w -= lr * gradient
    
    return w, losses

w, losses = linear_regression_gd(X, y, lr=0.1, epochs=100)
print(f"Learned: w0={w[0]:.3f}, w1={w[1]:.3f}")
print(f"True: w0=2, w1=3")

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].scatter(X, y, alpha=0.5)
axes[0].plot(X, w[0] + w[1]*X, 'r-', linewidth=2)
axes[0].set_title('Fit')
axes[1].plot(losses)
axes[1].set_title('Loss')
plt.show()

# %% [markdown]
# ## Key Observations
# - Gradient: (2/m) * X.T @ (X@w - y)
# - Learning rate controls convergence speed
# - Closed form: w = (X.T @ X)^(-1) @ X.T @ y
