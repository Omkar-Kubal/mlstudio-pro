# %% [markdown]
# # Control Flow and Functions
#
# Master Python control structures and function definitions.

# %%
# Conditionals
score = 85

if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
else:
    grade = 'F'

print(f"Score {score} → Grade {grade}")

# Ternary
status = 'pass' if score >= 60 else 'fail'
print(f"Status: {status}")

# %%
# Loops
# For loop with enumerate
items = ['a', 'b', 'c']
for i, item in enumerate(items):
    print(f"{i}: {item}")

# While loop
n = 0
while n < 3:
    print(f"n = {n}")
    n += 1

# Zip for parallel iteration
names = ['Alice', 'Bob']
scores = [95, 87]
for name, score in zip(names, scores):
    print(f"{name}: {score}")

# %%
# Functions
def mse(y_true, y_pred):
    """Compute Mean Squared Error."""
    n = len(y_true)
    error = sum((t - p)**2 for t, p in zip(y_true, y_pred))
    return error / n

y_true = [1, 2, 3]
y_pred = [1.1, 2.0, 2.9]
print(f"MSE: {mse(y_true, y_pred):.4f}")

# %%
# Lambda functions
square = lambda x: x ** 2
print(f"square(5) = {square(5)}")

# Map, filter, reduce
numbers = [1, 2, 3, 4, 5]
squared = list(map(lambda x: x**2, numbers))
evens = list(filter(lambda x: x % 2 == 0, numbers))

print(f"Squared: {squared}")
print(f"Evens: {evens}")

# %%
# Default arguments and *args, **kwargs
def train(model, lr=0.01, epochs=100, **kwargs):
    print(f"Training with lr={lr}, epochs={epochs}")
    for key, val in kwargs.items():
        print(f"  {key}={val}")

train('nn', lr=0.001, batch_size=32, verbose=True)

# %% [markdown]
# ## Key Observations
# - Use enumerate for index+value, zip for parallel iteration
# - Functions should have docstrings
# - Lambda for simple inline functions
# - **kwargs for flexible function signatures
